# %%
import numpy as np
import matplotlib.pyplot as plt
data_path = '/home/mabon/Cross_EM/datasets/TIME/stm_em/T2/S2_K3_150k_L11.npz'
whole_pack = np.load(data_path)

trace_array, textin_array= whole_pack['power_trace'], whole_pack['plain_text']

# %%
    
# Create a list of colors for each array

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(np.arange(0, 5001, 200))
plt.xlim(1200,2200)
plt.yticks(np.arange(-0.4,0.5, 0.2))
plt.ylim([-0.4,0.4])
plt.plot(trace_array[0],label='C11')
plt.legend(fontsize=20,loc='lower left')  # Change made here
plt.xlabel('Points of Interest',fontsize=25)
#plt.ylabel('mV',fontsize=25)
# Out:
# Text(0.5, 0, 'Points of Interest')
